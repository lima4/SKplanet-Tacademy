# %%
# 쥬피터노트북 셀 스타일 조절 
from IPython.core.display import display, HTML
display(HTML("<style>.container { font-weight: bold !important; }</style>"))
display(HTML("<style>.container { width: 100% !important; }</style>"))

# 경고 메세지 숨기기 
import warnings
warnings.filterwarnings(action='ignore')
# Out:
# <style>.container { font-weight: bold !important; }</style>
# <style>.container { width: 100% !important; }</style>

# %%
import numpy as np
import pandas as pd
import os
import matplotlib
# matplotlib의 pyplot을 사용한다.
import matplotlib.pyplot as plt

# 매직 명령어 => jupyter notebook에서 그래프 삽입 기능 
# %matplotlib inline
# 관련 라이브러리 임포트 
# 한글이 깨져 나오는것을 방지하기위해서 
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
matplotlib.rcParams['axes.unicode_minus'] = False

#  한글글꼴로 변경
plt.rcParams['font.size'] = 11.0
# plt.rcParams['font.family'] = 'batang'
# 한글 폰트 지정 
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.style.use('ggplot')

# %% [markdown]
# # Bar Plot
#
# - plt.bar(xData, yData, label=labelName, color=colorName, width=float)

# %%
x = range(10)
y = np.random.randint(10, 100, 10)
fig14 = plt.figure()

#plt.bar(xData, yData, label=labelName, color = colorName, width = float)
#width : 막대가로길이 0.1 ~ 1.1보다 작으면 막대 옆에 여백 생성, 기본은 0.8


fig14, plt.bar(x, y, width=0.9, color = 'red')
fig14, plt.title("Bar Plot Sample")
fig14, plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>, None)

# %%
x = range(10)
y = np.random.randint(10,100,10)
fig14 = plt.figure()
fig14, plt.bar(x,y,width=0.9,color='red')
fig14, plt.title('Bar Plot Sample')
fig14, plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>, None)

# %% [markdown]
# # barh plot
#
# - figure 변수 생성
# - subPlots() 가변
# ```
# figure, subplotVar = plt.subplots()
# ```
# - x, y 데이타 생성
# - subplotVar.barh(dataList, Value, color=color Name, widtgh=float)
# - y축의 눈금을 데이타로 지정하기
# ```
#  subplotVar.set_yticks(xData)
#  subplotVar.set_yticklabels(xDataList)
# ```

# %%
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim', 'Kyle') # xData 
# 총 데이타 길이
y_pos = np.arange(len(people))
# y 데이타 
performance = np.random.rand(len(people)) 

# 그래프 전체 변수 설정
fig16 = plt.figure(figsize=(4,4))

# 변수 ax는 그래프 변수 
fig16, ax = plt.subplots()

# 그래프 변수 
# 변수.barh(x, y, 옵션들 )
ax.barh(y_pos, performance, color='green')

# y축의 라벨 설정 
ax.set_yticks(y_pos)
ax.set_yticklabels(people)

# x축의 라벨 설정
ax.set_xlabel('Performance')

# 제목설정
ax.set_title('Today\' Man ')

fig16, plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>, None)

# %% [markdown]
# # Scatter Plot
#
# - fiqure 생성
# - plt.sctter(xData,yData,s=Size, c=colorName, marker=markerName)

# %%
# x
names = ['a', 'b', 'c', 'd', 'e']
# y
values = np.random.randint(30,50,5)

fig_s1 = plt.figure()
plt.scatter(names, values, s=200, c='blue')

# plt.scatter(names, values, s=200, c='blue', marker='x')
plt.title('Scatter Plot Sample')
plt.show()

# %%
# x
names = ['a', 'b', 'c', 'd', 'e']

# y
values = (1, 6, 2, 4, 6)

plt.figure()
plt.scatter(names, values, s=200, c='blue', marker='x') # 표시는 파란색 X로 한다. 
plt.suptitle('Scatter Plot Sample')
plt.show()

# %%
# x
names = ['a', 'b', 'c', 'd', 'e']

# y
values = np.random.randint(30,50,5)

fig_s1 = plt.figure()
fig_s1, plt.scatter(names, values, s=200, c='blue', marker='x') # 표시는 파란색 X로 한다. 
fig_s1, plt.suptitle('Scatter Plot Sample')
fig_s1, plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>, None)

# %% [markdown]
# # Pie Plot
#
# - plt.pie(values, labels=labelList, autopct='%digit.pointNum%Unit')

# %%
# Label + Value 
label_list = ['Frogs', 'Hogs', 'Dogs', 'Logs']
sizes = [15, 30, 45, 78]

fig_p1 = plt.figure(figsize=(5,5))
# fig_p1, plt.pie(sizes, labels=label_list, autopct='%.2f')
# fig_p1, plt.pie(sizes, labels=label_list, autopct='%.2f%%')
# fig_p1, plt.pie(sizes, labels=label_list, autopct='%.2f퍼센트')
fig_p1, plt.pie(sizes, labels=label_list, autopct='%d%%')
plt.show()

# %%
# Label + Value 
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
fig_p1 = plt.figure(figsize=(5,5))
# %를 지우려면 autopct = '%.2f'
# 일반숫자 = autopct = '%d'
fig_p1, plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # Pie Plot - Explode
#
# - plt.pie(dataValue, explode=explodeList, labels=labels, autopct='%digit.pointNum%Unit', shadow=True, startangle=angleValue)

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

#explode = (0.05, 0.1, 0.15, 0.05)  
explode = (0.1, 0.1, 0.1, 0.1) # 간격조정하기

fig_p2 = plt.figure(figsize=(5,5))
fig_p2, plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=180)

plt.show()

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

#explode = (0.05, 0.1, 0.15, 0.05)  
explode = (0.1, 0.1, 0.1, 0.1)

fig_p2 = plt.figure(figsize=(5,5))
fig_p2, plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle= 180)

plt.show()

# %% [markdown]
# # Histogram plot
#
# - figure 생성
# - plt.hist(dataVales, bins=number, color='colorName')

# %%
points = np.random.randn(10000)
print(points)

fig_hist = plt.figure()
# bins는 막대기 수 
fig_hist, plt.hist(points, bins=25, color='hotpink')

plt.show()
# Out:
# [-1.07929117  1.4878312  -0.61754107 ... -1.30185687 -1.39443435
#   1.84985808]

# %% [markdown]
# # 판다스의 데이타프레임 그래프

# %% [markdown]
# ### 데이타프레임
# 데이타프레임명.plot( kind=그래프형태, figsize=(가로,세로), title=제목)
#
# 그래프 형태는 ? bar/ barh/ line/ pie
#
# ### 시리즈
# 데이타프레임명[컬럼명].plot( kind=그래프형태, figsize=(가로,세로), title=제목)
#
# ### 서브플랏 스타일
# 데이타프레임명.plot( kind=그래프형태, figsize=(가로,세로), title=제목 ,
#                         subplots=True, layout(행수, 열수) )

# %%
data = {'kor':[40, 55, 66, 77, 34],
        'math':[70, 55, 66, 20, 40],
        'eng':[80, 95, 100, 77, 90],
        'sci':[90, 45, 77, 90, 67]}
        
name_list = ['고길동','김희동','신윤지','이민호','박준희']    

df = pd.DataFrame(data, index=name_list)
df
# Out:
#      kor  math  eng  sci
# 고길동   40    70   80   90
# 김희동   55    55   95   45
# 신윤지   66    66  100   77
# 이민호   77    20   77   90
# 박준희   34    40   90   67

# %%
df.plot(kind='bar', title='중간고사 성적', figsize=(8,5))
plt.tick_params(axis='x', labelsize=20, colors='black', width='3', rotation=45)

# %%
df.plot(kind='barh', title='중간고사 성적', figsize=(8,5))
plt.tick_params(axis='x', labelsize=20, colors='black', width='3', rotation=45)

# %%
df.plot(kind='barh', title='중간고사 성적', figsize=(8,5))
plt.tick_params(axis='y', labelsize=15, colors='black', width='3', rotation=45)

# %%
df.loc['고길동']
# Out:
# kor     40
# math    70
# eng     80
# sci     90
# Name: 고길동, dtype: int64

# %%
# 세로막대 그래프
# 색상지정을 안하면 파란색 그래프
#df.loc['고길동'].plot(kind='bar', title='고길동');

df.loc['고길동'].plot(kind='bar', title='고길동', color=['r','b','g','k']);

# %%
df['kor'].plot(kind='bar', title='국어', color=['g','r','c','m','y']);
plt.tick_params(axis='x', labelsize=15, colors='black', rotation=45);

# %%
plt.figure(figsize=(10,12))
plt.subplot(221)
df.iloc[0].plot(kind='bar', title=df.index[0], color=['r','b','g','c']);

plt.subplot(222)
df.iloc[1].plot(kind='bar', title=df.index[1], color=['r','b','g','c']);

plt.subplot(223)
df.iloc[2].plot(kind='bar', title=df.index[2], color=['r','b','g','c']);

plt.subplot(224)
df.iloc[3].plot(kind='bar', title=df.index[3], color=['r','b','g','c']);

plt.suptitle('학생별 중간고사 성적')
plt.axis('auto')
plt.show()

# %%
# for문을 사용하여 subplot 그리기
plt.figure(figsize=(10,12))
for i in range(4):    
    plt.subplot(221+i)
    df.iloc[i].plot(kind='bar', title=df.index[i], color=['r','b','g','c']);
# 전체 제목 설정
plt.suptitle('학생별 중간고사 성적')
plt.axis('auto')
plt.show()

# %% [markdown]
# # 레이아웃 변경: layout()

# %% [markdown]
# 데이타프레임명.plot(kind = 'bar', figsize = (10, 12), title = '중간고사 성적',
#                     subplots = True, grid = True, layout=(2,2), legend = False);
#
# ####

# %% [markdown]
# # layout=(2,2), subplots=True 삽입하면 컬럼별로 분리된 후 시각화
#
# df.plot(kind='bar', figsize=(10,12), title='중간고사 성적' , subplots=True,
#         grid=True, layout=(2,2), legend=False );
#
# plt.suptitle('학생별 중간고사 성적', fontsize=20)
# plt.show()

# %%
df.plot(kind='bar', figsize=(10,12), title='중간고사 성적' ,subplots=True,  
        grid=True, layout=(2,2), sharey=True, legend=False );

# %% [markdown]
# ## 서울의 온도 그래프 예시

# %%
df_weather = pd.read_csv('data/seoul.csv', encoding='cp949')
df_weather
# Out:
#                날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      1907-10-01  108     13.5      7.9     20.7
# 1      1907-10-02  108     16.2      7.9     22.0
# 2      1907-10-03  108     16.2     13.1     21.3
# 3      1907-10-04  108     16.5     11.2     22.0
# 4      1907-10-05  108     17.6     10.9     25.4
# ...           ...  ...      ...      ...      ...
# 40216  2019-01-13  108      1.2     -3.0      7.6
# 40217  2019-01-14  108      1.4     -2.4      5.3
# 40218  2019-01-15  108     -1.7     -7.2      2.6
# 40219  2019-01-16  108     -5.2    -10.1     -1.1
# 40220  2019-01-17  108     -0.3     -3.2      4.0
#
# [40221 rows x 5 columns]

# %% [markdown]
# ### 서울의 온도 간략정보

# %%
df_weather.shape
# Out:
# (40221, 5)

# %%
df_weather.head()
# Out:
#            날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  1907-10-01  108     13.5      7.9     20.7
# 1  1907-10-02  108     16.2      7.9     22.0
# 2  1907-10-03  108     16.2     13.1     21.3
# 3  1907-10-04  108     16.5     11.2     22.0
# 4  1907-10-05  108     17.6     10.9     25.4

# %%
df_weather['평균기온(℃)']
# Out:
# 0        13.5
# 1        16.2
# 2        16.2
# 3        16.5
# 4        17.6
#          ...
# 40216     1.2
# 40217     1.4
# 40218    -1.7
# 40219    -5.2
# 40220    -0.3
# Name: 평균기온(℃), Length: 40221, dtype: float64

# %%
# 특정 월을 보고싶다 2002년 5월 시각화, dtypes로 속성확인하기 
df_weather.dtypes
# Out:
# 날짜          object
# 지점           int64
# 평균기온(℃)    float64
# 최저기온(℃)    float64
# 최고기온(℃)    float64
# dtype: object

# %%
# 날짜 컬럼을 시계열 데이타로 변경 
df_weather['날짜'] = pd.to_datetime(df_weather['날짜'])
df_weather.dtypes
# Out:
# 날짜         datetime64[ns]
# 지점                  int64
# 평균기온(℃)           float64
# 최저기온(℃)           float64
# 최고기온(℃)           float64
# dtype: object

# %%
# 날짜 컬럼을 인덱스로 변경하기 
#df_weather['날짜'] 컬럼을 인덱스로 설정
df_weather.set_index(['날짜'], inplace=True)
df_weather
# Out:
#              지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 날짜
# 1907-10-01  108     13.5      7.9     20.7
# 1907-10-02  108     16.2      7.9     22.0
# 1907-10-03  108     16.2     13.1     21.3
# 1907-10-04  108     16.5     11.2     22.0
# 1907-10-05  108     17.6     10.9     25.4
# ...         ...      ...      ...      ...
# 2019-01-13  108      1.2     -3.0      7.6
# 2019-01-14  108      1.4     -2.4      5.3
# 2019-01-15  108     -1.7     -7.2      2.6
# 2019-01-16  108     -5.2    -10.1     -1.1
# 2019-01-17  108     -0.3     -3.2      4.0
#
# [40221 rows x 4 columns]

# %%
# 2002-05 월 데이타만 추출 
df_weather2 = df_weather['2002-05']
df_weather2
# Out:
#              지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 날짜
# 2002-05-01  108     18.9     11.6     25.7
# 2002-05-02  108     18.3     11.6     25.3
# 2002-05-03  108     16.0     12.4     19.6
# 2002-05-04  108     19.1     13.6     25.9
# 2002-05-05  108     19.6     14.1     25.2
# 2002-05-06  108     15.6     11.1     19.7
# 2002-05-07  108     11.4     10.6     12.0
# 2002-05-08  108     16.6     10.0     23.1
# 2002-05-09  108     18.3     13.2     23.4
# 2002-05-10  108     18.5     14.3     23.1
# 2002-05-11  108     17.9     14.2     23.5
# 2002-05-12  108     16.4     12.2     22.3
# 2002-05-13  108     18.3     12.5     24.9
# 2002-05-14  108     21.3     15.4     25.6
# 2002-05-15  108     18.1     13.9     22.0
# 2002-05-16  108     14.9     12.6     17.3
# 2002-05-17  108     13.4     11.2     15.3
# 2002-05-18  108     16.9     11.6     23.6
# 2002-05-19  108     17.3     13.1     22.1
# 2002-05-20  108     19.3     13.5     25.9
# 2002-05-21  108     19.6     13.6     25.7
# 2002-05-22  108     20.0     15.8     26.0
# 2002-05-23  108     21.9     15.6     27.7
# 2002-05-24  108     19.9     15.3     25.3
# 2002-05-25  108     19.9     14.0     26.6
# 2002-05-26  108     18.5     14.0     24.3
# 2002-05-27  108     18.6     12.5     25.3
# 2002-05-28  108     19.3     14.1     25.3
# 2002-05-29  108     20.6     13.8     27.0
# 2002-05-30  108     19.1     15.4     24.5
# 2002-05-31  108     19.4     16.4     25.7

# %%
df_weather2.drop(['지점'], axis=1, inplace=True)
df_weather2
# Out:
#             평균기온(℃)  최저기온(℃)  최고기온(℃)
# 날짜
# 2002-05-01     18.9     11.6     25.7
# 2002-05-02     18.3     11.6     25.3
# 2002-05-03     16.0     12.4     19.6
# 2002-05-04     19.1     13.6     25.9
# 2002-05-05     19.6     14.1     25.2
# 2002-05-06     15.6     11.1     19.7
# 2002-05-07     11.4     10.6     12.0
# 2002-05-08     16.6     10.0     23.1
# 2002-05-09     18.3     13.2     23.4
# 2002-05-10     18.5     14.3     23.1
# 2002-05-11     17.9     14.2     23.5
# 2002-05-12     16.4     12.2     22.3
# 2002-05-13     18.3     12.5     24.9
# 2002-05-14     21.3     15.4     25.6
# 2002-05-15     18.1     13.9     22.0
# 2002-05-16     14.9     12.6     17.3
# 2002-05-17     13.4     11.2     15.3
# 2002-05-18     16.9     11.6     23.6
# 2002-05-19     17.3     13.1     22.1
# 2002-05-20     19.3     13.5     25.9
# 2002-05-21     19.6     13.6     25.7
# 2002-05-22     20.0     15.8     26.0
# 2002-05-23     21.9     15.6     27.7
# 2002-05-24     19.9     15.3     25.3
# 2002-05-25     19.9     14.0     26.6
# 2002-05-26     18.5     14.0     24.3
# 2002-05-27     18.6     12.5     25.3
# 2002-05-28     19.3     14.1     25.3
# 2002-05-29     20.6     13.8     27.0
# 2002-05-30     19.1     15.4     24.5
# 2002-05-31     19.4     16.4     25.7

# %%
df_weather2.plot(figsize = (10,12), title = '서울의 기온', subplots = True, grid = True, layout=(3,1), marker = 'o');
