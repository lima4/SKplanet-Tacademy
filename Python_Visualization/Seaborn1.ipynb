# %% [markdown]
# # LinePlot()
# - sns.lineplot(x=컬럼명1, y=컬럼명2, data=데이타프레임명, 옵션=값)

# %%
# 쥬피터노트북 셀 스타일 조절 
from IPython.core.display import display, HTML
display(HTML("<style>.container { font-weight: bold !important; }</style>"))
display(HTML("<style>.container { width: 100% !important; }</style>"))

# 경고 메세지 숨기기 
import warnings
warnings.filterwarnings(action='ignore')
# Out:
# <style>.container { font-weight: bold !important; }</style>
# <style>.container { width: 100% !important; }</style>

# %%
import numpy as np
import pandas as pd
import os

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# 관련 라이브러리 임포트 
import matplotlib.font_manager as fm

#  한글글꼴로 변경
# plt.rcParams['font.family'] = '한글글꼴명'
plt.rcParams['font.size'] = 11.0
# plt.rcParams['font.family'] = 'batang'
plt.rcParams['font.family'] = 'Malgun Gothic'

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
matplotlib.rcParams['axes.unicode_minus'] = False

# 그래프 기본 크기 설정 
plt.rcParams['figure.figsize'] = [10, 6]

plt.style.use('ggplot')

# %%
iris = sns.load_dataset("iris")    # 붓꽃 데이터
titanic = sns.load_dataset("titanic")    # 타이타닉호 데이터
tips = sns.load_dataset("tips")    # 팁 데이터
flights = sns.load_dataset("flights")    # 여객운송 데이터
penguins = sns.load_dataset("penguins") # 펭귄

# %%
# 넘파이 데이타를 이용해서 그래프 출력 
xData = np.linspace(-5, 5, 1000)
yData = np.sin(xData)
sns.lineplot(x=xData, y=yData);

# %%
xData = np.linspace(-5, 5, 1000)
yData = np.sin(xData)
sns.lineplot(x=xData, y=yData)
plt.title('Sin')
# Out:
# Text(0.5, 1.0, 'Sin')

# %%
sns.lineplot(x='tip', y='total_bill', data=tips, marker='o', color='r', linestyle='--');

# %%
# ax 변수 설정 방식 
ax = sns.lineplot(x='tip', y='total_bill', data=tips)
ax.set_title('Tip and Total Bill')
ax.set_xlabel('Tip')
ax.set_ylabel('Total Bill')
# plt.show()
ax
# Out:
# <AxesSubplot:title={'center':'Tip and Total Bill'}, xlabel='Tip', ylabel='Total Bill'>

# %% [markdown]
# # countplot()
# - sns.countplot(컬럼명, data=데이타프레임, 옵션=값)
# - 범주형 데이타에서 사용.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
# 세로 막대형 
sns.countplot(x='day', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
# 가로 막대형, 성별에 대한 값들 보여주기
sns.countplot(y='day', data=tips, hue='sex');

# %%
sns.countplot(x='sex', data=tips);

# %%
ax = sns.countplot('day', data=tips)
ax.set_title('count of days') # 제목
ax.set_xlabel('day of week') # x축 이름
ax.set_ylabel('Frequency') # y축 이름
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # sns.regplot()
#
# - 회귀 + 산점도
#
# sns.regplot(x=컬럼명1, y=컬럼명2, data=데이타프레임,  fit_reg=True)

# %%
# 빙어의 길이와 무게 리스트 정의 
smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
# sns.regplot(x=smelt_length, y=smelt_weight, fit_reg=False);
sns.regplot(x=smelt_length, y=smelt_weight);

# %%
# 회귀분석과 산점도 모두
sns.regplot(x='tip', y='total_bill', data=tips);

# %%
# fit_reg 옵션으로 회귀선을 제거할 수 있다.
fig, ax = plt.subplots()

ax = sns.regplot(x=smelt_length, y=smelt_weight, fit_reg=True)

ax.set_title('regplot 그래프')
ax.set_xlabel('smelt_length')
ax.set_ylabel('smelt_weight')

ax;

# %% [markdown]
# # joinplot()
#
# - 산점도+히스토그램
#
# sns.jointplot(x=컬럼명1, y=컬럼명2, data=데이타프레임)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, alpha=0.5);

# %%
# 육각형(hexbin) = 겹치게 되는 데이타는 진하게 표시 
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex');

# %% [markdown]
# # violinplot()
#
# sns.violinplot(x=컬럼명1, y=컬럼명2, data=데이타프레임)
#
# x 축은 범주형
# y 툭은 수치형

# %%
sns.violinplot(x='time', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
# 남녀 성별 + 점심 저녁 
sns.violinplot(x='time', y='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
# 남녀 성별 + 점심 저녁 
sns.violinplot(x='sex', y='total_bill', data=tips, hue='time')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
# 남녀 성별 + 점심 저녁 
sns.violinplot(x='sex', y='total_bill', data=tips, hue='time', split=True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # barplot()
#
# sns.barplot(x=컬럼명1, y=컬럼명2, data=데이타프레임)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips[['time','total_bill']].head()
# Out:
#      time  total_bill
# 0  Dinner       16.99
# 1  Dinner       10.34
# 2  Dinner       21.01
# 3  Dinner       23.68
# 4  Dinner       24.59

# %%
sns.barplot(x='time', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
# x 축이 수치형, y 가 범주형 
sns.barplot(y='time', x='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='time'>

# %%
# x 축이 범주형 , y 가 수치형
# dodge=False 각각의 막대그래프가 겹쳐서 보이는 형태 
sns.barplot(y='total_bill', x='time', data=tips, hue='sex', dodge=False)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
# x 축이 범주형 , y 가 수치형
sns.barplot(y='total_bill', x='time', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
# x 축이 범주형 , y 가 수치형
# dodge=False 각각의 막대그래프가 겹쳐서 보이는 형태 
# sns.barplot(y='tip', x='day', data=tips, hue='sex', dodge=False)
sns.barplot(y='tip', x='day', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# x 축이 범주형 , y 가 수치형
# dodge=False 각각의 막대그래프가 겹쳐서 보이는 형태 
# sns.barplot(y='tip', x='day', data=tips, hue='sex', dodge=False)
sns.barplot(y='tip', x='day', data=tips, hue='sex', dodge=False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# # Boxplot 그래프
#
# ```
# 최솟값, 1분위수, 중간값, 3분위수, 최댓값, 이상치를 표시
#
# sns.boxplot(x=컬럼명1, y=컬럼명2, data=데이타프레임)
# ```

# %%
tips[['time', 'total_bill']].tail()
# Out:
#        time  total_bill
# 239  Dinner       29.03
# 240  Dinner       27.18
# 241  Dinner       22.67
# 242  Dinner       17.82
# 243  Dinner       18.78

# %%
sns.boxplot(x='time', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(x='total_bill', y='time', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='time'>

# %%
sns.boxplot(x='smoker', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %% [markdown]
# # 관계 그래프 (PairGrid)
#
#
# - 그래프 형태가 같다.
#
# 그래프변수 = sns.PairGrid(데이타프레임)
#
# 그래프변수.map(sns.그래프)

# %%
# 그래프 형태가 같다 
pair_grid = sns.PairGrid(tips)
pair_grid.map(sns.regplot)
plt.show()

# %%
# 그래프 형태가 같다 
pair_grid = sns.PairGrid(tips)
pair_grid.map(sns.lineplot)
plt.show()

# %% [markdown]
# 그래프변수 = sns.PairGrid(데이타프레임명)
#
# 그래프변수.map_diag(그래프1, 옵션=값) # 대각선그래프
#
# 그래프변수.map_offdiag(그래프2, 옵션=값) # 대각선이외의 그래프

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_diag(plt.hist, edgecolor="w")
pair_grid = pair_grid.map_offdiag(plt.scatter, edgecolor="b")
plt.show()

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_diag(plt.plot)
pair_grid = pair_grid.map_offdiag(sns.regplot)
plt.show()

# %% [markdown]
# # pairplot
#
#
# ```
# pairplot은 데이터프레임을 인수로 받아 그리드(grid) 형태로 각 데이터 열의 조합에 대해 스캐터 플롯을 그린다.
#
# pairplot: http://seaborn.pydata.org/generated/seaborn.pairplot.html
#
# ```

# %%
sns.pairplot(tips)

# %%
# hue 값을 지정하면 대각선은 밀집선 
sns.pairplot(tips, hue="sex", markers=["o", "s"])

# %% [raw]
# '.' point marker
# '' pixel marker
# 'o' circle marker
# 'v' triangle_down marker
# '^' triangle_up marker
# '<' triangle_left marker
# '>' triangle_right marker
# '1' tri_down marker
# '2' tri_up marker
# '3' tri_left marker
# '4' tri_right marker
# 's' square marker
# 'p' pentagon marker
# '*' star marker
# 'h' hexagon1 marker
# 'H' hexagon2 marker
# '+' plus marker
# 'x' x marker
# 'D' diamond marker
# 'd' thin_diamond marker
# '|' vline marker
# '_' hline marker

# %%
# hue 값을 지정하면 대각선은 밀집선 
sns.pairplot(tips, hue="day", markers=["o", "s", "D", "p"])

# %% [markdown]
# # 다른 데이터셋 활용하기

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## 데이터셋 세부정보

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
titanic['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
titanic['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
titanic['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
titanic['deck'].value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: deck, dtype: int64

# %%
titanic['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic[titanic.isnull()['embark_town']]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
titanic['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
titanic['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# # 카운트플랏

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic["class"].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(x="class", data=titanic);

# %%
# 각 등급별 생존/사망 
sns.countplot(x="class", data=titanic, hue='survived');

# %%
# 성별 생존/사망 
sns.countplot(x="sex", data=titanic, hue='survived');

# %%
# 여자/남자/아동 에 따른  생존/사망 
sns.countplot(x="who", data=titanic, hue='survived');

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# ## 히트맵(Heat Map)
#
# - X축과 Y축에 2개의 범주형 자료값에 비례하여 색깔을 다르게 해서 2차원으로 자료를 시각화하는데 사용한다.
# - sns.heatmap(data, op)

# %%
data = np.random.rand(30,30)
sns.heatmap(data);

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic2 = titanic[['age', 'survived', 'fare']]
titanic2
# Out:
#       age  survived     fare
# 0    22.0         0   7.2500
# 1    38.0         1  71.2833
# 2    26.0         1   7.9250
# 3    35.0         1  53.1000
# 4    35.0         0   8.0500
# ..    ...       ...      ...
# 886  27.0         0  13.0000
# 887  19.0         1  30.0000
# 888   NaN         0  23.4500
# 889  26.0         1  30.0000
# 890  32.0         0   7.7500
#
# [891 rows x 3 columns]

# %%
sns.heatmap(titanic2[:12]);

# %% [markdown]
# ### flights 데이타셋 로딩
#
# 연도(year)별 월(month)별 승객 수(passengers)
#
# 데이타프레임변수 = sns.load_dataset('flights')

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
flights['year'].unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960], dtype=int64)

# %%
# year와 passengers 컬럼을 이용한 그래프 
sns.lineplot(x='year', y='passengers', data=flights);

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_pv = flights.pivot('month', 'year', 'passengers')
flights_pv
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
# 상관계수 
flights_pv.corr()
# Out:
# year      1949      1950      1951      1952      1953      1954      1955  \
# year
# 1949  1.000000  0.949435  0.944994  0.905623  0.970144  0.911553  0.908190
# 1950  0.949435  1.000000  0.946923  0.957062  0.880477  0.930967  0.949866
# 1951  0.944994  0.946923  1.000000  0.923131  0.939609  0.959165  0.939515
# 1952  0.905623  0.957062  0.923131  1.000000  0.861005  0.942879  0.956044
# 1953  0.970144  0.880477  0.939609  0.861005  1.000000  0.913945  0.884986
# 1954  0.911553  0.930967  0.959165  0.942879  0.913945  1.000000  0.989433
# 1955  0.908190  0.949866  0.939515  0.956044  0.884986  0.989433  1.000000
# 1956  0.940419  0.938707  0.946961  0.960854  0.929524  0.984947  0.985527
# 1957  0.933350  0.934320  0.946232  0.963146  0.928578  0.986983  0.982708
# 1958  0.912513  0.904400  0.911054  0.960107  0.907120  0.962541  0.961328
# 1959  0.901456  0.927191  0.947280  0.962860  0.902622  0.988882  0.984109
# 1960  0.887272  0.887417  0.894268  0.925008  0.894288  0.965944  0.974451
#
# year      1956      1957      1958      1959      1960
# year
# 1949  0.940419  0.933350  0.912513  0.901456  0.887272
# 1950  0.938707  0.934320  0.904400  0.927191  0.887417
# 1951  0.946961  0.946232  0.911054  0.947280  0.894268
# 1952  0.960854  0.963146  0.960107  0.962860  0.925008
# 1953  0.929524  0.928578  0.907120  0.902622  0.894288
# 1954  0.984947  0.986983  0.962541  0.988882  0.965944
# 1955  0.985527  0.982708  0.961328  0.984109  0.974451
# 1956  1.000000  0.997125  0.983194  0.983704  0.977851
# 1957  0.997125  1.000000  0.986762  0.988408  0.977076
# 1958  0.983194  0.986762  1.000000  0.980656  0.976757
# 1959  0.983704  0.988408  0.980656  1.000000  0.977292
# 1960  0.977851  0.977076  0.976757  0.977292  1.000000

# %%
# annot=True 값, 구분선 표시
sns.heatmap(flights_pv, annot=True, fmt='d', linewidths=.1);
# sns.heatmap(flights_pv, annot=True, fmt='d', linewidths=.1)

# %% [raw]
# cmap
# #  'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
# #     'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
# #      'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn'

# %%
# annot=True 값, 구분선 표시
sns.heatmap(flights_pv, annot=True, fmt='d', linewidths=.1, cmap='Blues_r');
# sns.heatmap(flights_pv, annot=True, fmt='d', linewidths=.1)

# %%
# flights_pv.corr() => 상관계수 구한 데이타프레임 => 히트맵 
sns.heatmap(flights_pv.corr(), annot=True, linewidths=.1, cmap='Blues');

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# ## tips 데이타프레임에서 'total_bill', 'tip' 컬럼의 상관계수를 이용한 히트맵

# %%
tips[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
tips[['total_bill', 'tip']].corr().loc['tip', 'total_bill' ]
# Out:
# 0.6757341092113648

# %%
df3 = tips[['total_bill', 'tip']]

# %%
df3['total_bill'].corr(df3['tip'])
# Out:
# 0.6757341092113641

# %%
sns.heatmap(tips[['total_bill', 'tip']].corr(), cmap='YlOrBr')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 그래프 스타일 지정
#
# darkgrid, whitegrid, dark, white, ticks
#
# sns.set_style(styleName)

# %%
# shade=True
data = np.random.randn(200)
sns.kdeplot(data, shade=True);

# %%
sns.set_style('whitegrid')
sns.kdeplot(data, shade=True);

# %%
sns.set_style('dark')
sns.kdeplot(data, shade=True);

# %%
sns.set_style('ticks')
sns.kdeplot(data, shade=True);
